# %%
frame = pd.read_csv('dataset', header = 0, sep = '\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-528c608c8099> in <module>
# ----> 1 frame = pd.read_csv('dataset', header = 0, sep = '\t')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
frame = pd.DataFrame({'numbers':range(10), 'chars':['a']*10})

# %%
frame
# Out:
#    numbers chars
# 0        0     a
# 1        1     a
# 2        2     a
# 3        3     a
# 4        4     a
# 5        5     a
# 6        6     a
# 7        7     a
# 8        8     a
# 9        9     a

# %%
frame = pd.read_csv('dataset.tsv', header = 0, sep = '\t')

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер

# %%
frame.columns
# Out:
# Index(['Name', 'Birth', 'City', 'Position'], dtype='object')

# %%
frame.shape
# Out:
# (6, 4)

# %%
new_line = {'Name' : 'Перов', 'Birth' : '22.03.1990', 'City' : 'Penza'}

# %%
frame = frame.append(new_line, ignore_index = True)

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6            Перов  22.03.1990      Penza       NaN

# %%
frame['Is Student'] = [False]* 5 + [True]* 2

# %%
frame
# Out:
#               Name       Birth       City  Position  Is Student
# 0      Иванов А.А.  22.03.1980     Москва       NaN       False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер       False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер       False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN       False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер       False
# 5     Костров С.О.  31.05.1985     Москва    стажер        True
# 6            Перов  22.03.1990      Penza       NaN        True

# %%
job = 'Employee'

# %%
frame[job] = [False]* 5 + [True]* 2

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6            Перов  22.03.1990      Penza       NaN

# %%
frame['Is Student']
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# Name: Is Student, dtype: bool

# %%
frame.drop([5, 6], axis = 0)
# Out:
#               Name       Birth       City  Position  Is Student  Employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN       False     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер       False     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер       False     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN       False     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер       False     False

# %%
frame
# Out:
#               Name       Birth       City  Position  Is Student  Employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN       False     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер       False     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер       False     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN       False     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер       False     False
# 5     Костров С.О.  31.05.1985     Москва    стажер        True      True
# 6            Перов  22.03.1990      Penza       NaN        True      True

# %%
frame.drop([5, 6], axis = 0, inplace = True)

# %%
frame
# Out:
#               Name       Birth       City  Position  Is Student  Employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN       False     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер       False     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер       False     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN       False     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер       False     False

# %%
frame.drop('Is Student', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-c44d8cf7efa2> in <module>
# ----> 1 frame.drop('Is Student', axis = 1, inplace = True)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6            Перов  22.03.1990      Penza       NaN

# %%
frame = frame.drop('Is Student', axis = 1)
frame
# Out:
#               Name       Birth       City  Position  Employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер     False

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6            Перов  22.03.1990      Penza       NaN

# %%
frame.to_csv('datasets/updated_dataset.csv', sep = ',', header = True, index = False)

# %%
frame
# Out:
#               Name       Birth       City  Position  Employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер     False

# %%
frame = frame.drop('Employee', axis = 1)
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер

# %%
frame.dtypes
# Out:
# Name        object
# Birth       object
# City        object
# Position    object
# dtype: object

# %%
frame.Birth = frame.Birth.apply(pd.to_datetime)

# %%
frame.dtypes
# Out:
# Name                object
# Birth       datetime64[ns]
# City                object
# Position            object
# dtype: object

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 4 columns):
# Name        5 non-null object
# Birth       5 non-null datetime64[ns]
# City        5 non-null object
# Position    3 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 200.0+ bytes

# %%
frame.fillna('разнорабочий')
# Out:
#               Name      Birth       City      Position
# 0      Иванов А.А. 1980-03-22     Москва  разнорабочий
# 1     Сорокин И.В. 1965-07-08  Волгоград       инженер
# 2       Белов М.М. 1980-02-13     Ростов      менеджер
# 3  Мельникова Д.С. 1985-04-15     Ростов  разнорабочий
# 4      Рыбина Е.П. 1985-11-19     Москва       инженер

# %%
frame
# Out:
#               Name      Birth       City  Position
# 0      Иванов А.А. 1980-03-22     Москва       NaN
# 1     Сорокин И.В. 1965-07-08  Волгоград   инженер
# 2       Белов М.М. 1980-02-13     Ростов  менеджер
# 3  Мельникова Д.С. 1985-04-15     Ростов       NaN
# 4      Рыбина Е.П. 1985-11-19     Москва   инженер

# %%
frame.fillna('разнорабочий', inplace = True)

# %%
frame
# Out:
#               Name      Birth       City      Position
# 0      Иванов А.А. 1980-03-22     Москва  разнорабочий
# 1     Сорокин И.В. 1965-07-08  Волгоград       инженер
# 2       Белов М.М. 1980-02-13     Ростов      менеджер
# 3  Мельникова Д.С. 1985-04-15     Ростов  разнорабочий
# 4      Рыбина Е.П. 1985-11-19     Москва       инженер

# %%
frame[['Name', 'Position']]
# Out:
#               Name      Position
# 0      Иванов А.А.  разнорабочий
# 1     Сорокин И.В.       инженер
# 2       Белов М.М.      менеджер
# 3  Мельникова Д.С.  разнорабочий
# 4      Рыбина Е.П.       инженер

# %%
frame[:3]
# Out:
#            Name      Birth       City      Position
# 0   Иванов А.А. 1980-03-22     Москва  разнорабочий
# 1  Сорокин И.В. 1965-07-08  Волгоград       инженер
# 2    Белов М.М. 1980-02-13     Ростов      менеджер

# %%
frame[-3:]
# Out:
#               Name      Birth    City      Position
# 2       Белов М.М. 1980-02-13  Ростов      менеджер
# 3  Мельникова Д.С. 1985-04-15  Ростов  разнорабочий
# 4      Рыбина Е.П. 1985-11-19  Москва       инженер

# %%
frame.head(3)
# Out:
#            Name      Birth       City      Position
# 0   Иванов А.А. 1980-03-22     Москва  разнорабочий
# 1  Сорокин И.В. 1965-07-08  Волгоград       инженер
# 2    Белов М.М. 1980-02-13     Ростов      менеджер

# %%
frame.tail(3)
# Out:
#               Name      Birth    City      Position
# 2       Белов М.М. 1980-02-13  Ростов      менеджер
# 3  Мельникова Д.С. 1985-04-15  Ростов  разнорабочий
# 4      Рыбина Е.П. 1985-11-19  Москва       инженер

# %%
frame.loc[[0, 1, 2], ['Name', 'City']]
# Out:
#            Name       City
# 0   Иванов А.А.     Москва
# 1  Сорокин И.В.  Волгоград
# 2    Белов М.М.     Ростов

# %%
frame.iloc[[1, 3, 4], [0,1]]
# Out:
#               Name      Birth
# 1     Сорокин И.В. 1965-07-08
# 3  Мельникова Д.С. 1985-04-15
# 4      Рыбина Е.П. 1985-11-19

# %%
frame.loc[[0, 1, 2], ['Name', 'Birth']]
# Out:
#            Name      Birth
# 0   Иванов А.А. 1980-03-22
# 1  Сорокин И.В. 1965-07-08
# 2    Белов М.М. 1980-02-13

# %%
frame.ix[[0, 1, 2], ['Name','City']]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#            Name       City
# 0   Иванов А.А.     Москва
# 1  Сорокин И.В.  Волгоград
# 2    Белов М.М.     Ростов

# %%
frame[frame.Birth >= pd.datetime(1985, 1, 1)]
# Out:
#               Name      Birth    City      Position
# 3  Мельникова Д.С. 1985-04-15  Ростов  разнорабочий
# 4      Рыбина Е.П. 1985-11-19  Москва       инженер

# %%
frame[(frame.Birth >= pd.datetime(1985, 1, 1)) & (frame.City != 'Москва')]
# Out:
#               Name      Birth    City      Position
# 3  Мельникова Д.С. 1985-04-15  Ростов  разнорабочий

# %%
frame[(frame.Birth >= pd.datetime(1985, 1, 1)) | (frame.City == 'Волгоград')]
# Out:
#               Name      Birth       City      Position
# 1     Сорокин И.В. 1965-07-08  Волгоград       инженер
# 3  Мельникова Д.С. 1985-04-15     Ростов  разнорабочий
# 4      Рыбина Е.П. 1985-11-19     Москва       инженер
