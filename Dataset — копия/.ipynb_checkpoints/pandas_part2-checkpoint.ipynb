# %%
import pandas as pd
import numpy as np

# %%
mydict={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'day':['sunny','rainy','hot','sunny','hot'],
         'wind-speed':[12,34,45,56,67],
         'temp':[45,46,47,48,49]
       }

df=pd.DataFrame(mydict)

df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46
# 2  04-01-12    hot          45    47
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %%
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46
# 2  04-01-12    hot          45    47
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %%
# размеры датасета
df.shape
# Out:
# (5, 4)

# %%
# распечатать только поля 'day','temp'
df[['day', 'temp']]
# Out:
#      day  temp
# 0  sunny    45
# 1  rainy    46
# 2    hot    47
# 3  sunny    48
# 4    hot    49

# %%
# статистика
df.describe()
# Out:
#        wind-speed       temp
# count    5.000000   5.000000
# mean    42.800000  47.000000
# std     21.158922   1.581139
# min     12.000000  45.000000
# 25%     34.000000  46.000000
# 50%     45.000000  47.000000
# 75%     56.000000  48.000000
# max     67.000000  49.000000

# %%
# записать в переменную d1 значения из таблицы d, у которых температура больше 9 градусов
# d1=d[d['Temperature (C)']>9]
# d1
d1 = df[df['temp'] > 9]
d1
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46
# 2  04-01-12    hot          45    47
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %%
# размеры таблицы d1
d1.shape
# Out:
# (5, 4)

# %%
# df=pd.read_excel('titanic.xls')
# df.head()
df=pd.read_excel('titanic.xls')
df.head(25)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# 19       1         0                               Beattie, Mr. Thomson
#
#        sex     age  sibsp  parch    ticket      fare    cabin embarked  boat  \
# 0   female      29      0      0     24160  211.3375       B5        S     2
# 1     male  0.9167      1      2    113781  151.5500  C22 C26        S    11
# 2   female       2      1      2    113781  151.5500  C22 C26        S  None
# 3     male      30      1      2    113781  151.5500  C22 C26        S  None
# 4   female      25      1      2    113781  151.5500  C22 C26        S  None
# 5     male      48      0      0     19952   26.5500      E12        S     3
# 6   female      63      1      0     13502   77.9583       D7        S    10
# 7     male      39      0      0    112050    0.0000      A36        S  None
# 8   female      53      2      0     11769   51.4792     C101        S     D
# 9     male      71      0      0  PC 17609   49.5042     None        C  None
# 10    male      47      1      0  PC 17757  227.5250  C62 C64        C  None
# 11  female      18      1      0  PC 17757  227.5250  C62 C64        C     4
# 12  female      24      0      0  PC 17477   69.3000      B35        C     9
# 13  female      26      0      0     19877   78.8500     None        S     6
# 14    male      80      0      0     27042   30.0000      A23        S     B
# 15    male    None      0      0  PC 17318   25.9250     None        S  None
# 16    male      24      0      1  PC 17558  247.5208  B58 B60        C  None
# 17  female      50      0      1  PC 17558  247.5208  B58 B60        C     6
# 18  female      32      0      0     11813   76.2917      D15        C     8
# 19    male      36      0      0     13050   75.2417       C6        C     A
#
#     body                        home.dest
# 0   None                     St Louis, MO
# 1   None  Montreal, PQ / Chesterville, ON
# 2   None  Montreal, PQ / Chesterville, ON
# 3    135  Montreal, PQ / Chesterville, ON
# 4   None  Montreal, PQ / Chesterville, ON
# 5   None                     New York, NY
# 6   None                       Hudson, NY
# 7   None                      Belfast, NI
# 8   None              Bayside, Queens, NY
# 9     22              Montevideo, Uruguay
# 10   124                     New York, NY
# 11  None                     New York, NY
# 12  None                    Paris, France
# 13  None                             None
# 14  None                    Hessle, Yorks
# 15  None                     New York, NY
# 16  None                     Montreal, PQ
# 17  None                     Montreal, PQ
# 18  None                             None
# 19  None                     Winnipeg, MN

# %%
# запись данных в файл csv
df.to_csv('mycsv.csv',index=False)

# %%
# запись данных в файл excel
df.to_excel('myexcel.xls',index=False)

# %%
# все поля
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# запись только определенных полей
df.to_csv('mycsv_few_columns.csv',columns=['name','body','age'],index=False)

#  проверка результата
d=pd.read_csv('mycsv_few_columns.csv')
d
# Out:
#                                                  name  body     age
# 0                       Allen, Miss. Elisabeth Walton  None      29
# 1                      Allison, Master. Hudson Trevor  None  0.9167
# 2                        Allison, Miss. Helen Loraine  None       2
# 3                Allison, Mr. Hudson Joshua Creighton   135      30
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  None      25
# 5                                 Anderson, Mr. Harry  None      48
# 6                   Andrews, Miss. Kornelia Theodosia  None      63
# 7                              Andrews, Mr. Thomas Jr  None      39
# 8       Appleton, Mrs. Edward Dale (Charlotte Lamson)  None      53
# 9                             Artagaveytia, Mr. Ramon    22      71
# 10                             Astor, Col. John Jacob   124      47
# 11  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  None      18
# 12                      Aubart, Mme. Leontine Pauline  None      24
# 13                       Barber, Miss. Ellen "Nellie"  None      26
# 14               Barkworth, Mr. Algernon Henry Wilson  None      80
# 15                                Baumann, Mr. John D  None    None
# 16                           Baxter, Mr. Quigg Edmond  None      24
# 17    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  None      50
# 18                              Bazzani, Miss. Albina  None      32
# 19                               Beattie, Mr. Thomson  None      36

# %%
# данные по погоде
weather1={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'day':['sunny','rainy','hot','sunny','hot'],
         'wind-speed':[12,34,45,56,67],
         'temp':[45,46,47,48,49]
       }

weather=pd.DataFrame(weather1)

# данные по домам
house1={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'price':[20000,30000,40000,50000,60000],
         'bhk':[1,3,2,1,2],
         'how-old':[2,5,2,7,4]
       }

house=pd.DataFrame(house1)

# %%
with pd.ExcelWriter('weather_and_house.xls') as writer:
   weather.to_excel(writer,sheet_name='Weather',index=False)
   house.to_excel(writer,sheet_name='House',index=False)

# %%
 house.to_excel('weather_and_house.xls',sheet_name='House',index=False)

# %%
house
# Out:
#       dates  price  bhk  how-old
# 0  02-01-12  20000    1        2
# 1  03-01-12  30000    3        5
# 2  04-01-12  40000    2        2
# 3  05-01-12  50000    1        7
# 4  06-01-12  60000    2        4

# %% [markdown]
# ### Группировка

# %%
h = house.groupby('bhk')
h

# %%
for bhk,bhkdata in h:
    print(bhk)
    print("-"*10)
    print(bhkdata)
    print("-"*35)
# Out:
# 1
# ----------
#       dates  price  bhk  how-old
# 0  02-01-12  20000    1        2
# 3  05-01-12  50000    1        7
# -----------------------------------
# 2
# ----------
#       dates  price  bhk  how-old
# 2  04-01-12  40000    2        2
# 4  06-01-12  60000    2        4
# -----------------------------------
# 3
# ----------
#       dates  price  bhk  how-old
# 1  03-01-12  30000    3        5
# -----------------------------------

# %%
h.get_group(1)
# Out:
#       dates  price  bhk  how-old
# 0  02-01-12  20000    1        2
# 3  05-01-12  50000    1        7

# %%
h.min()
# Out:
#         dates  price  how-old
# bhk
# 1    02-01-12  20000        2
# 2    04-01-12  40000        2
# 3    03-01-12  30000        5

# %%
g_yr=house.groupby('how-old')
g_yr['price'].agg([np.min,np.max,np.mean,np.sum,np.std])
# Out:
#           amin   amax   mean    sum           std
# how-old
# 2        20000  40000  30000  60000  14142.135624
# 4        60000  60000  60000  60000           NaN
# 5        30000  30000  30000  30000           NaN
# 7        50000  50000  50000  50000           NaN

# %% [markdown]
# ### Упражнение

# %%
d={
    'team':["India","New zealand","Australia","India",
            "India","New zealand","Australia","India",
            "New zealand","Australia","New zealand","Australia"],
     'Run':[330,230,300,180,200,250,190,400,340,290,390,333],
     "Match":[2,4,2,1,5,6,3,2,5,3,1,1],
     "Year":['2012','2012','2012','2012','2013','2013','2013','2013','2014','2014','2014','2014']
  }
df=pd.DataFrame(d)
df
# Out:
#            team  Run  Match  Year
# 0         India  330      2  2012
# 1   New zealand  230      4  2012
# 2     Australia  300      2  2012
# 3         India  180      1  2012
# 4         India  200      5  2013
# 5   New zealand  250      6  2013
# 6     Australia  190      3  2013
# 7         India  400      2  2013
# 8   New zealand  340      5  2014
# 9     Australia  290      3  2014
# 10  New zealand  390      1  2014
# 11    Australia  333      1  2014

# %%
# создать группы по полю team

# %%
# распечатать значения в каждой группе

# %%
# распечатать только группу Австралия

# %%
# Для каждого года, определить максимальную, минимальную, среднюю, сумму и стандартное отклонение поля Run

# %% [markdown]
# ### Конкатенация таблиц

# %%
chennai={
      "date":['01-02-12','03-02-12','04-02-12','05-02-12'],
      "event":['hot','sunny','rainy','cold'],
      "wind-speed":[33,23,45,24],
      "temp":[20,21,15,18]
}
chen=pd.DataFrame(chennai)
chen
# Out:
#        date  event  wind-speed  temp
# 0  01-02-12    hot          33    20
# 1  03-02-12  sunny          23    21
# 2  04-02-12  rainy          45    15
# 3  05-02-12   cold          24    18

# %%
kolkata={
      "date":['01-02-12','03-02-12','04-02-12','05-02-12'],
      "event":['sunny','cold','cold','rainy'],
      "wind-speed":[12,10,9,14],
      "temp":[14,16,15,10]
}
kol=pd.DataFrame(kolkata)
kol
# Out:
#        date  event  wind-speed  temp
# 0  01-02-12  sunny          12    14
# 1  03-02-12   cold          10    16
# 2  04-02-12   cold           9    15
# 3  05-02-12  rainy          14    10

# %%
df=pd.concat([kol,chen])
df
# Out:
#        date  event  wind-speed  temp
# 0  01-02-12  sunny          12    14
# 1  03-02-12   cold          10    16
# 2  04-02-12   cold           9    15
# 3  05-02-12  rainy          14    10
# 0  01-02-12    hot          33    20
# 1  03-02-12  sunny          23    21
# 2  04-02-12  rainy          45    15
# 3  05-02-12   cold          24    18

# %%
df=pd.concat([kol,chen],ignore_index=True)
df
# Out:
#        date  event  wind-speed  temp
# 0  01-02-12  sunny          12    14
# 1  03-02-12   cold          10    16
# 2  04-02-12   cold           9    15
# 3  05-02-12  rainy          14    10
# 4  01-02-12    hot          33    20
# 5  03-02-12  sunny          23    21
# 6  04-02-12  rainy          45    15
# 7  05-02-12   cold          24    18

# %%
df=pd.concat([kol,chen],axis=1)
df
# Out:
#        date  event  wind-speed  temp      date  event  wind-speed  temp
# 0  01-02-12  sunny          12    14  01-02-12    hot          33    20
# 1  03-02-12   cold          10    16  03-02-12  sunny          23    21
# 2  04-02-12   cold           9    15  04-02-12  rainy          45    15
# 3  05-02-12  rainy          14    10  05-02-12   cold          24    18

# %%
df.columns
# Out:
# Index(['date', 'event', 'wind-speed', 'temp', 'date', 'event', 'wind-speed',
#        'temp'],
#       dtype='object')

# %%
df.event
# Out:
#    event  event
# 0  sunny    hot
# 1   cold  sunny
# 2   cold  rainy
# 3  rainy   cold

# %% [markdown]
# ### Join таблиц

# %%
temp1={
      "date":['01-02-12','03-02-12','04-02-12','05-02-12'],
      "event":['sunny','cold','cold','rainy'],
      "temp":[14,16,15,10]
}
temp=pd.DataFrame(temp1)
temp
# Out:
#        date  event  temp
# 0  01-02-12  sunny    14
# 1  03-02-12   cold    16
# 2  04-02-12   cold    15
# 3  05-02-12  rainy    10

# %%
ws={
      "date":['01-02-12','03-02-12','04-02-12','05-02-12'],
      "event":['sunny','cold','cold','rainy'],
      "wind-speed":[12,10,9,14],
}
wind_speed=pd.DataFrame(ws)
wind_speed
# Out:
#        date  event  wind-speed
# 0  01-02-12  sunny          12
# 1  03-02-12   cold          10
# 2  04-02-12   cold           9
# 3  05-02-12  rainy          14

# %%
df=pd.merge(temp,wind_speed,on=['date','event'])
df
# Out:
#        date  event  temp  wind-speed
# 0  01-02-12  sunny    14          12
# 1  03-02-12   cold    16          10
# 2  04-02-12   cold    15           9
# 3  05-02-12  rainy    10          14

# %%
temp1={
      "date":['01-02-12','03-02-12','04-02-12','05-02-12'],
      "event":['sunny','cold','hot','sunny'],
      "temp":[14,16,15,10]
}
temp=pd.DataFrame(temp1)
temp
# Out:
#        date  event  temp
# 0  01-02-12  sunny    14
# 1  03-02-12   cold    16
# 2  04-02-12    hot    15
# 3  05-02-12  sunny    10

# %%
ws={
      "date":['01-02-12','03-02-12','04-02-12','05-02-12'],
      "event":['sunny','cold','cold','rainy'],
      "wind-speed":[12,10,9,14],
}
wind_speed=pd.DataFrame(ws)
wind_speed
# Out:
#        date  event  wind-speed
# 0  01-02-12  sunny          12
# 1  03-02-12   cold          10
# 2  04-02-12   cold           9
# 3  05-02-12  rainy          14

# %%
df=pd.merge(temp,wind_speed,on=['date','event'],how='outer')
df
# Out:
#        date  event  temp  wind-speed
# 0  01-02-12  sunny  14.0        12.0
# 1  03-02-12   cold  16.0        10.0
# 2  04-02-12    hot  15.0         NaN
# 3  05-02-12  sunny  10.0         NaN
# 4  04-02-12   cold   NaN         9.0
# 5  05-02-12  rainy   NaN        14.0

# %%
# left join для таблицы temp
# Out:
#        date  event  temp  wind-speed
# 0  01-02-12  sunny    14        12.0
# 1  03-02-12   cold    16        10.0
# 2  04-02-12    hot    15         NaN
# 3  05-02-12  sunny    10         NaN

# %%
# right join для таблицы temp
