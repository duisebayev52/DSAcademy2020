# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
# df = pd.read_excel("August'2015.xlsx", index_col=0)
df = pd.read_csv("BlackFriday.csv")

# %%
age_sorted = sorted(df['Age'].unique())
min_ps = []
mean_ps = []
max_ps = []
for age in age_sorted:
    df_f = df[df["Age"] == age]
    desc = df_f['Purchase'].describe()
    print(age, desc['min'], round(desc['mean'], 3), desc['max'])
    min_ps.append(desc['min'])
    mean_ps.append(desc['mean'])
    max_ps.append(desc['max'])
df_age_aggr = pd.DataFrame({
    "min": min_ps,
    "mean": mean_ps,
    "max": max_ps
}, index=age_sorted)
# Out:
# 0-17 187.0 9020.127 23955.0
# 18-25 185.0 9235.198 23958.0
# 26-35 185.0 9314.589 23961.0
# 36-45 185.0 9401.479 23960.0
# 46-50 186.0 9284.872 23960.0
# 51-55 187.0 9620.617 23960.0
# 55+ 187.0 9453.899 23960.0

# %%
df_age_aggr
# Out:
#          min         mean      max
# 0-17   187.0  9020.126878  23955.0
# 18-25  185.0  9235.197575  23958.0
# 26-35  185.0  9314.588970  23961.0
# 36-45  185.0  9401.478758  23960.0
# 46-50  186.0  9284.872277  23960.0
# 51-55  187.0  9620.616620  23960.0
# 55+    187.0  9453.898579  23960.0

# %%
df_age_aggr.to_excel("Отчёт по возрастам.xlsx", encoding="utf-8")

# %%
df[df['Gender'] == "M"]['Purchase'].describe()
# Out:
# count    405380.000000
# mean       9504.771713
# std        5051.057256
# min         185.000000
# 25%        5901.000000
# 50%        8112.000000
# 75%       12542.000000
# max       23961.000000
# Name: Purchase, dtype: float64

# %%
df[df['Gender'] == "F"]['Purchase'].describe()
# Out:
# count    132197.000000
# mean       8809.761349
# std        4721.440055
# min         185.000000
# 25%        5459.000000
# 50%        7929.000000
# 75%       11436.000000
# max       23959.000000
# Name: Purchase, dtype: float64

# %%
# regions = df["MARKET_KEY"].unique()
# max_average_check = 0
# max_region = None
# for r in regions:
#     df_f = df[df['MARKET_KEY'] == r]
#     average_check = round(df_f['REVENUE_TOTAL'].mean(), 1)
#     if max_average_check < average_check:
#         max_region = r
#         max_average_check = average_check
#     print(r, len(df_f), "человек,", average_check, "тенге")
# print(max_region, max_average_check)
df[['REVENUE_TOTAL', 'MARKET_KEY']].groupby('MARKET_KEY').mean()
# df[df['REVENUE_TOTAL'] > 2000].groupby('MARKET_KEY')['ID'].count()
# Out:
#             REVENUE_TOTAL
# MARKET_KEY
# AKT            862.958000
# AST           2282.419568
# ATB            881.978183
# ATR            624.160643
# KAR            753.917965
# KOS            683.681118
# KZO           1147.803886
# KZT            828.998000
# ORA            974.135160
# OSK            995.106129
# PTP            855.776800
# PVL            699.657875
# SHM            527.546187
# TRZ            785.786041

# %%
df["MARKET_KEY"].unique()
# Out:
# array(['KZT', 'KOS', 'KZO', 'ORA', 'TRZ', 'AST', 'OSK', 'SHM', 'PVL',
#        'KAR', 'PTP', 'AKT', 'ATR', 'ATB'], dtype=object)

# %% [markdown]
# ### CSV Output

# %%
df[df['REVENUE_TOTAL'] < 20000]['REVENUE_TOTAL'].plot.hist(bins=100)

# %%
df[df['REVENUE_TOTAL'] < 100]['REVENUE_TOTAL'].plot.hist(bins=50)

# %%
df['MARKET_KEY'].value_counts()
# Out:
# KZT    191
# SHM    134
# OSK     85
# AST     81
# ATB     71
# KOS     68
# PVL     64
# KAR     57
# ORA     50
# TRZ     49
# KZO     35
# PTP     35
# AKT     25
# ATR     14
# Name: MARKET_KEY, dtype: int64

# %%
df[['REVENUE_TOTAL', 'REVENUE_VOICE', 'REVENUE_DATA', 'TRAFFIC_DATA']].plot.box()

# %%
df.describe()
# Out:
#        REVENUE_TOTAL  REVENUE_VOICE   REVENUE_DATA  TRAFFIC_DATA          MOU
# count     959.000000     959.000000     959.000000    959.000000   959.000000
# mean      920.750579     487.013005     238.741911    288.345119   319.182648
# std      3554.652556     713.225269    3442.259779   1401.879960   411.832858
# min         0.000000       0.000000       0.000000      0.000000     0.000000
# 25%       143.031500      33.044500       0.000000      0.000000    42.099500
# 50%       484.213000     249.447000       0.000000      0.000000   173.966000
# 75%      1104.009000     677.611500      26.513500      4.121500   437.392000
# max    106166.820000    7209.236000  106166.820000  26869.049000  2887.349000

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')
# Out:
# C:\Users\KindYAK\Anaconda3\envs\def\lib\site-packages\pandas\util\_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('!asff.xlsx', sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0]
# Out:
#                                              Bank Name                City  \
# 0                                 The Enloe State Bank              Cooper
# 1                  Washington Federal Bank for Savings             Chicago
# 2      The Farmers and Merchants State Bank of Argonia             Argonia
# 3                                  Fayette County Bank          Saint Elmo
# 4    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 5                                       First NBC Bank         New Orleans
# 6                                        Proficio Bank  Cottonwood Heights
# 7                        Seaway Bank and Trust Company             Chicago
# 8                               Harvest Community Bank          Pennsville
# 9                                          Allied Bank            Mulberry
# 10                        The Woodbury Banking Company            Woodbury
# ...

# %% [markdown]
# ____

# %% [markdown]
# # Great Job!
